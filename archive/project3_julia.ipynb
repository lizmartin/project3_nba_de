# %%
# Dependencies
import pandas as pd
from pathlib import Path

# %%
games_details_path = Path('games_details.csv')
games_path = ('games.csv')

# %%
games_details = pd.read_csv(games_details_path)
games_details
# Out:
# /var/folders/bb/4gpn5xfn0dqcx7v7w_7s2llc0000gn/T/ipykernel_94670/2683507017.py:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   games_details = pd.read_csv(games_details_path)
#          GAME_ID     TEAM_ID TEAM_ABBREVIATION    TEAM_CITY  PLAYER_ID  \
# 0       22200477  1610612759               SAS  San Antonio    1629641
# 1       22200477  1610612759               SAS  San Antonio    1631110
# 2       22200477  1610612759               SAS  San Antonio    1627751
# 3       22200477  1610612759               SAS  San Antonio    1630170
# 4       22200477  1610612759               SAS  San Antonio    1630200
# ...          ...         ...               ...          ...        ...
# 668623  11200005  1610612743               DEN       Denver     202706
# 668624  11200005  1610612743               DEN       Denver     202702
# 668625  11200005  1610612743               DEN       Denver     201585
# ...

# %%
games = pd.read_csv(games_path)
games.head()
# Out:
#   GAME_DATE_EST   GAME_ID GAME_STATUS_TEXT  HOME_TEAM_ID  VISITOR_TEAM_ID  \
# 0    2022-12-22  22200477            Final    1610612740       1610612759
# 1    2022-12-22  22200478            Final    1610612762       1610612764
# 2    2022-12-21  22200466            Final    1610612739       1610612749
# 3    2022-12-21  22200467            Final    1610612755       1610612765
# 4    2022-12-21  22200468            Final    1610612737       1610612741
#
#    SEASON  TEAM_ID_home  PTS_home  FG_PCT_home  FT_PCT_home  ...  AST_home  \
# 0    2022    1610612740     126.0        0.484        0.926  ...      25.0
# 1    2022    1610612762     120.0        0.488        0.952  ...      16.0
# 2    2022    1610612739     114.0        0.482        0.786  ...      22.0
# 3    2022    1610612755     113.0        0.441        0.909  ...      27.0
# 4    2022    1610612737     108.0        0.429        1.000  ...      22.0
#
# ...

# %%
season_2022 = games[games['SEASON'] == 2022]['GAME_ID'].unique()
season_2022
# Out:
# array([22200477, 22200478, 22200466, 22200467, 22200468, 22200469,
#        22200470, 22200471, 22200472, 22200473, 22200474, 22200475,
#        22200476, 22200461, 22200462, 22200463, 22200464, 22200465,
#        22200452, 22200453, 22200454, 22200455, 22200456, 22200457,
#        22200458, 22200459, 22200460, 22200445, 22200446, 22200447,
#        22200448, 22200449, 22200450, 22200451, 22200438, 22200439,
#        22200440, 22200441, 22200442, 22200443, 22200444, 22200428,
#        22200429, 22200430, 22200431, 22200432, 22200433, 22200434,
#        22200435, 22200436, 22200437, 22200424, 22200425, 22200426,
#        22200427, 22200414, 22200415, 22200416, 22200417, 22200418,
#        22200419, 22200420, 22200421, 22200422, 22200423, 22200409,
#        22200410, 22200411, 22200412, 22200413, 22200402, 22200403,
#        22200404, 22200405, 22200406, 22200407, 22200408, 22200395,
#        22200396, 22200397, 22200398, 22200399, 22200400, 22200401,
# ...

# %%
season_2022_details = games_details[games_details['GAME_ID'].isin(season_2022)].dropna(subset=['START_POSITION'])
season_2022_details
# Out:
#         GAME_ID     TEAM_ID TEAM_ABBREVIATION    TEAM_CITY  PLAYER_ID  \
# 0      22200477  1610612759               SAS  San Antonio    1629641
# 1      22200477  1610612759               SAS  San Antonio    1631110
# 2      22200477  1610612759               SAS  San Antonio    1627751
# 3      22200477  1610612759               SAS  San Antonio    1630170
# 4      22200477  1610612759               SAS  San Antonio    1630200
# ...         ...         ...               ...          ...        ...
# 14639  12200001  1610612764               WAS   Washington    1628398
# 14640  12200001  1610612764               WAS   Washington    1629060
# 14641  12200001  1610612764               WAS   Washington     204001
# 14642  12200001  1610612764               WAS   Washington     203078
# 14643  12200001  1610612764               WAS   Washington    1628420
#
#               PLAYER_NAME  NICKNAME START_POSITION COMMENT    MIN  ...  OREB  \
# ...

# %%
games.shape[0]
# Out:
# 26651

# %%
games_details.columns.to_list()
# Out:
# ['GAME_ID',
#  'TEAM_ID',
#  'TEAM_ABBREVIATION',
#  'TEAM_CITY',
#  'PLAYER_ID',
#  'PLAYER_NAME',
#  'NICKNAME',
#  'START_POSITION',
#  'COMMENT',
#  'MIN',
#  'FGM',
#  'FGA',
#  'FG_PCT',
#  'FG3M',
#  'FG3A',
#  'FG3_PCT',
#  'FTM',
#  'FTA',
#  'FT_PCT',
#  'OREB',
#  'DREB',
#  'REB',
#  'AST',
#  'STL',
#  'BLK',
#  'TO',
#  'PF',
#  'PTS',
#  'PLUS_MINUS']

# %%
games_details.shape[0]
# Out:
# 668628

# %%
games_2022_array = games[games['GAME_DATE_EST'].str.startswith('2022')]['GAME_ID'].unique()
games_2022_array
# Out:
# array([22200477, 22200478, 22200466, ..., 22100542, 22100543, 22100544])

# %%
games_details_2022 = games_details[games_details['GAME_ID'].isin(games_2022_array)]
games_details_2022
# Out:
#         GAME_ID     TEAM_ID TEAM_ABBREVIATION    TEAM_CITY  PLAYER_ID  \
# 0      22200477  1610612759               SAS  San Antonio    1629641
# 1      22200477  1610612759               SAS  San Antonio    1631110
# 2      22200477  1610612759               SAS  San Antonio    1627751
# 3      22200477  1610612759               SAS  San Antonio    1630170
# 4      22200477  1610612759               SAS  San Antonio    1630200
# ...         ...         ...               ...          ...        ...
# 34834  22100544  1610612762               UTA         Utah    1630215
# 34835  22100544  1610612762               UTA         Utah    1630238
# 34836  22100544  1610612762               UTA         Utah    1630235
# 34837  22100544  1610612762               UTA         Utah    1630190
# 34838  22100544  1610612762               UTA         Utah    1629671
#
#           PLAYER_NAME NICKNAME START_POSITION                 COMMENT    MIN  \
# ...

# %%
starters = games_details_2022.dropna(subset=['START_POSITION'])
starters
# Out:
#         GAME_ID     TEAM_ID TEAM_ABBREVIATION    TEAM_CITY  PLAYER_ID  \
# 0      22200477  1610612759               SAS  San Antonio    1629641
# 1      22200477  1610612759               SAS  San Antonio    1631110
# 2      22200477  1610612759               SAS  San Antonio    1627751
# 3      22200477  1610612759               SAS  San Antonio    1630170
# 4      22200477  1610612759               SAS  San Antonio    1630200
# ...         ...         ...               ...          ...        ...
# 34826  22100544  1610612762               UTA         Utah     202711
# 34827  22100544  1610612762               UTA         Utah    1626220
# 34828  22100544  1610612762               UTA         Utah     203497
# 34829  22100544  1610612762               UTA         Utah    1628378
# 34830  22100544  1610612762               UTA         Utah     201144
#
#             PLAYER_NAME NICKNAME START_POSITION COMMENT    MIN  ...  OREB  \
# ...

# %%
starters_stats = starters[['PLAYER_NAME',
 'FGM',
 'FGA',
 'FG_PCT',
 'FG3M',
 'FG3A',
 'FG3_PCT',
 'FTM',
 'FTA',
 'FT_PCT',
 'OREB',
 'DREB',
 'REB',
 'AST',
 'STL',
 'BLK',
 'TO',
 'PF',
 'PTS']]
starters_stats
# Out:
#             PLAYER_NAME  FGM   FGA  FG_PCT  FG3M  FG3A  FG3_PCT   FTM   FTA  \
# 0        Romeo Langford  1.0   1.0   1.000   0.0   0.0    0.000   0.0   0.0
# 1         Jeremy Sochan  7.0  14.0   0.500   2.0   4.0    0.500   7.0  10.0
# 2          Jakob Poeltl  6.0   9.0   0.667   0.0   0.0    0.000   1.0   1.0
# 3         Devin Vassell  4.0  13.0   0.308   1.0   6.0    0.167   1.0   1.0
# 4             Tre Jones  7.0  12.0   0.583   1.0   3.0    0.333   4.0   4.0
# ...                 ...  ...   ...     ...   ...   ...      ...   ...   ...
# 34826  Bojan Bogdanovic  7.0  14.0   0.500   4.0  10.0    0.400   2.0   2.0
# 34827     Royce O'Neale  5.0   7.0   0.714   2.0   4.0    0.500   3.0   4.0
# 34828       Rudy Gobert  9.0  10.0   0.900   0.0   0.0    0.000   2.0   4.0
# 34829  Donovan Mitchell  4.0  19.0   0.211   2.0   9.0    0.222  10.0  11.0
# 34830       Mike Conley  4.0  13.0   0.308   2.0   6.0    0.333   2.0   4.0
#
# ...

# %%
starter_mins = starters[['PLAYER_NAME', 'MIN',
 'FGM',
 'FGA',
 'FG_PCT',
 'FG3M',
 'FG3A',
 'FG3_PCT',
 'FTM',
 'FTA',
 'FT_PCT',
 'OREB',
 'DREB',
 'REB',
 'AST',
 'STL',
 'BLK',
 'TO',
 'PF',
 'PTS']]
   
starter_mins[starter_mins['PLAYER_NAME'] == 'Stephen Curry']
# Out:
#          PLAYER_NAME    MIN   FGM   FGA  FG_PCT  FG3M  FG3A  FG3_PCT   FTM  \
# 1399   Stephen Curry  29:33  11.0  19.0   0.579   5.0  10.0    0.500  11.0
# 1649   Stephen Curry  27:19   6.0  17.0   0.353   3.0  10.0    0.300   5.0
# 2242   Stephen Curry  37:26  12.0  21.0   0.571   6.0  11.0    0.545   2.0
# 3167   Stephen Curry  37:42   3.0  17.0   0.176   2.0  10.0    0.200   4.0
# 3517   Stephen Curry  34:32  10.0  21.0   0.476   8.0  17.0    0.471   2.0
# ...              ...    ...   ...   ...     ...   ...   ...      ...   ...
# 32816  Stephen Curry  38:42   8.0  21.0   0.381   2.0   9.0    0.222   9.0
# 33272  Stephen Curry  36:31  10.0  21.0   0.476   4.0  11.0    0.364   4.0
# 33963  Stephen Curry  36:04   5.0  24.0   0.208   1.0   9.0    0.111   3.0
# 34436  Stephen Curry  32:01   3.0  17.0   0.176   1.0  10.0    0.100   2.0
# 34816  Stephen Curry  35:32   8.0  18.0   0.444   6.0  12.0    0.500   6.0
#
# ...

# %%
season_2022[['PLAYER_NAME',
 'FGM',
 'FGA',
 'FG_PCT',
 'FG3M',
 'FG3A',
 'FG3_PCT',
 'FTM',
 'FTA',
 'FT_PCT',
 'OREB',
 'DREB',
 'REB',
 'AST',
 'STL',
 'BLK',
 'TO',
 'PF',
 'PTS']]
starters_2022
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /Users/juliaolson/Data-Analytics-Bootcamp/Projects/Project3/project3_nba_de/data/project3_julia.ipynb Cell 15 line 1
# ----> <a href='vscode-notebook-cell:/Users/juliaolson/Data-Analytics-Bootcamp/Projects/Project3/project3_nba_de/data/project3_julia.ipynb#X36sZmlsZQ%3D%3D?line=0'>1</a> season_2022[['PLAYER_NAME',
#       <a href='vscode-notebook-cell:/Users/juliaolson/Data-Analytics-Bootcamp/Projects/Project3/project3_nba_de/data/project3_julia.ipynb#X36sZmlsZQ%3D%3D?line=1'>2</a>  'FGM',
#       <a href='vscode-notebook-cell:/Users/juliaolson/Data-Analytics-Bootcamp/Projects/Project3/project3_nba_de/data/project3_julia.ipynb#X36sZmlsZQ%3D%3D?line=2'>3</a>  'FGA',
# ...

# %%
starters_avgs = starters_stats.groupby('PLAYER_NAME').mean().reset_index()
starters_avgs
# Out:
#          PLAYER_NAME       FGM        FGA    FG_PCT      FG3M      FG3A  \
# 0         AJ Griffin  5.875000  13.000000  0.460250  2.125000  6.625000
# 1       Aaron Gordon  6.098765  11.172840  0.541333  1.111111  3.246914
# 2      Aaron Holiday  2.375000   7.375000  0.296875  0.500000  2.875000
# 3      Aaron Nesmith  3.444444   7.666667  0.430389  1.444444  4.222222
# 4      Aaron Wiggins  3.705882   8.323529  0.442353  0.852941  2.970588
# ..               ...       ...        ...       ...       ...       ...
# 459      Zach LaVine  7.371429  16.442857  0.437943  2.557143  6.942857
# 460   Zavier Simpson  4.750000  13.000000  0.354250  0.250000  2.000000
# 461       Zeke Nnaji  3.000000   7.000000  0.429000  0.000000  3.000000
# 462  Ziaire Williams  3.757576   8.060606  0.456515  1.363636  4.272727
# 463  Zion Williamson  8.862069  14.862069  0.595655  0.241379  0.655172
#
#       FG3_PCT       FTM       FTA    FT_PCT      OREB      DREB       REB  \
# ...

# %%
starters_avgs[starters_avgs['PLAYER_NAME'] == 'Stephen Curry']
# Out:
#        PLAYER_NAME    FGM      FGA    FG_PCT  FG3M     FG3A  FG3_PCT     FTM  \
# 406  Stephen Curry  8.725  18.8625  0.454037   4.1  10.5125   0.3835  4.3875
#
#         FTA    FT_PCT    OREB    DREB    REB     AST     STL     BLK     TO  \
# 406  4.8375  0.832275  0.4875  5.1875  5.675  6.4125  1.0625  0.2875  2.975
#
#          PF      PTS
# 406  2.1875  25.9375

# %%
highest_FGM = starters_avgs.sort_values(by='FGM', ascending=False)
highest_FGM
# Out:
#                              FGM        FGA    FG_PCT      FG3M      FG3A  \
# PLAYER_NAME
# LeBron James           11.017241  21.706897  0.503224  2.431034  7.379310
# Cam Thomas             11.000000  18.000000  0.611000  4.000000  8.000000
# Giannis Antetokounmpo  10.923077  20.294872  0.541692  0.910256  3.294872
# Luka Doncic            10.377778  21.977778  0.470956  3.133333  8.822222
# Joel Embiid            10.179487  19.858974  0.510218  1.153846  3.500000
# ...                          ...        ...       ...       ...       ...
# Jaylin Williams         0.000000   1.000000  0.000000  0.000000  1.000000
# Yuta Watanabe           0.000000   2.000000  0.000000  0.000000  1.000000
# Elfrid Payton           0.000000   3.000000  0.000000  0.000000  0.000000
# Keljin Blevins          0.000000   3.000000  0.000000  0.000000  3.000000
# Udonis Haslem           0.000000   4.000000  0.000000  0.000000  0.000000
#
# ...

# %%
higest_FGA = starters_avgs.sort_values(by='FGA', ascending=False)
higest_FGA
# Out:
#                         FGM        FGA    FG_PCT      FG3M      FG3A  \
# PLAYER_NAME
# Luka Doncic       10.377778  21.977778  0.470956  3.133333  8.822222
# LeBron James      11.017241  21.706897  0.503224  2.431034  7.379310
# Devin Booker       9.937500  21.100000  0.462838  2.600000  7.037500
# Ja Morant         10.000000  21.071429  0.472071  1.542857  4.800000
# Donovan Mitchell   9.356164  20.397260  0.462123  3.561644  9.356164
# ...                     ...        ...       ...       ...       ...
# Dewayne Dedmon     1.000000   2.000000  0.500000  0.000000  1.000000
# Yuta Watanabe      0.000000   2.000000  0.000000  0.000000  1.000000
# Ed Davis           0.000000   2.000000  0.000000  0.000000  0.000000
# Nerlens Noel       1.000000   1.000000  1.000000  0.000000  0.000000
# Jaylin Williams    0.000000   1.000000  0.000000  0.000000  1.000000
#
#                    FG3_PCT       FTM       FTA    FT_PCT      OREB       DREB  \
# PLAYER_NAME
# ...

# %%
highest_FG_PCT = starters_avgs.sort_values(by='FG_PCT', ascending=False)
highest_FG_PCT
# Out:
#                    FGM        FGA    FG_PCT  FG3M  FG3A  FG3_PCT  FTM  \
# PLAYER_NAME
# Nerlens Noel       1.0   1.000000  1.000000   0.0   0.0     0.00  0.0
# Jordan McLaughlin  5.0   6.000000  0.833000   2.0   2.0     1.00  0.0
# Marques Bolden     9.0  11.000000  0.818000   3.0   4.0     0.75  0.0
# Jericho Sims       3.0   3.857143  0.809571   0.0   0.0     0.00  1.0
# Walker Kessler     4.6   5.800000  0.802200   0.0   0.0     0.00  0.6
# ...                ...        ...       ...   ...   ...      ...  ...
# Jaylin Williams    0.0   1.000000  0.000000   0.0   1.0     0.00  1.0
# Yuta Watanabe      0.0   2.000000  0.000000   0.0   1.0     0.00  0.0
# Keljin Blevins     0.0   3.000000  0.000000   0.0   3.0     0.00  0.0
# Elfrid Payton      0.0   3.000000  0.000000   0.0   0.0     0.00  1.0
# Ed Davis           0.0   2.000000  0.000000   0.0   0.0     0.00  2.0
#
#                         FTA    FT_PCT      OREB       DREB   REB       AST  \
# PLAYER_NAME
# ...

# %%
starters['PLAYER_NAME'].unique()
# Out:
# array(['Romeo Langford', 'Jeremy Sochan', 'Jakob Poeltl', 'Devin Vassell',
#        'Tre Jones', 'Trey Murphy III', 'Naji Marshall',
#        'Jonas Valanciunas', 'Herbert Jones', 'CJ McCollum',
#        'Corey Kispert', 'Kyle Kuzma', 'Daniel Gafford', 'Bradley Beal',
#        'Monte Morris', 'Lauri Markkanen', 'Jarred Vanderbilt',
#        'Walker Kessler', 'Jordan Clarkson', 'Mike Conley',
#        'MarJon Beauchamp', 'Giannis Antetokounmpo', 'Brook Lopez',
#        'Grayson Allen', 'Jrue Holiday', 'Isaac Okoro', 'Evan Mobley',
#        'Jarrett Allen', 'Donovan Mitchell', 'Darius Garland',
#        'Bojan Bogdanovic', 'Isaiah Stewart', 'Jalen Duren', 'Jaden Ivey',
#        'Killian Hayes', 'Tobias Harris', 'P.J. Tucker', 'Joel Embiid',
#        "De'Anthony Melton", 'James Harden', 'DeMar DeRozan',
#        'Patrick Williams', 'Nikola Vucevic', 'Zach LaVine', 'Alex Caruso',
#        "De'Andre Hunter", 'John Collins', 'Onyeka Okongwu',
# ...

# %%
games_details_2022
# Out:
#         GAME_ID     TEAM_ID TEAM_ABBREVIATION    TEAM_CITY  PLAYER_ID  \
# 0      22200477  1610612759               SAS  San Antonio    1629641
# 1      22200477  1610612759               SAS  San Antonio    1631110
# 2      22200477  1610612759               SAS  San Antonio    1627751
# 3      22200477  1610612759               SAS  San Antonio    1630170
# 4      22200477  1610612759               SAS  San Antonio    1630200
# ...         ...         ...               ...          ...        ...
# 34834  22100544  1610612762               UTA         Utah    1630215
# 34835  22100544  1610612762               UTA         Utah    1630238
# 34836  22100544  1610612762               UTA         Utah    1630235
# 34837  22100544  1610612762               UTA         Utah    1630190
# 34838  22100544  1610612762               UTA         Utah    1629671
#
#           PLAYER_NAME NICKNAME START_POSITION                 COMMENT    MIN  \
# ...

# %%
games_details_2022['START_POSITION'].unique()
# Out:
# array(['F', 'C', 'G', nan], dtype=object)
